# %% [markdown]
# # 1.6 Intro to NLP and Network Analysis

# %% [markdown]
# ## 2. Import Libraries

# %%
import pandas as pd
import numpy as np
import spacy
from spacy import displacy
import networkx as nx
import os
import matplotlib.pyplot as plt
import scipy
import re

# %%
# Download English module
# !python -m spacy download en_core_web_sm
# Out:
# Collecting en-core-web-sm==3.7.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.7.1/en_core_web_sm-3.7.1-py3-none-any.whl (12.8 MB)
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ---------------------------------------- 0.1/12.8 MB 1.9 MB/s eta 0:00:07
#       --------------------------------------- 0.2/12.8 MB 1.6 MB/s eta 0:00:08
#      - -------------------------------------- 0.5/12.8 MB 3.2 MB/s eta 0:00:04
#      -- ------------------------------------- 0.8/12.8 MB 4.0 MB/s eta 0:00:04
#      --- ------------------------------------ 1.3/12.8 MB 5.1 MB/s eta 0:00:03
#      ----- ---------------------------------- 1.8/12.8 MB 6.0 MB/s eta 0:00:02
#      ------- -------------------------------- 2.3/12.8 MB 6.7 MB/s eta 0:00:02
#      --------- ------------------------------ 2.9/12.8 MB 7.4 MB/s eta 0:00:02
#      ----------- ---------------------------- 3.6/12.8 MB 8.2 MB/s eta 0:00:02
#      ------------- -------------------------- 4.4/12.8 MB 8.7 MB/s eta 0:00:01
#      ---------------- ----------------------- 5.3/12.8 MB 9.7 MB/s eta 0:00:01
#      ------------------- -------------------- 6.2/12.8 MB 10.4 MB/s eta 0:00:01
#      --------------------- ------------------ 6.9/12.8 MB 11.0 MB/s eta 0:00:01
#      ------------------------ --------------- 8.0/12.8 MB 11.8 MB/s eta 0:00:01
#      ---------------------------- ----------- 9.2/12.8 MB 12.6 MB/s eta 0:00:01
#      ------------------------------- ------- 10.5/12.8 MB 15.6 MB/s eta 0:00:01
#      ------------------------------------ -- 12.0/12.8 MB 19.2 MB/s eta 0:00:01
#      --------------------------------------  12.8/12.8 MB 20.5 MB/s eta 0:00:01
#      --------------------------------------- 12.8/12.8 MB 19.3 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.2 in c:\users\bhimc\anaconda3\envs\20th_century\lib\site-packages (from en-core-web-sm==3.7.1) (3.7.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\bhimc\anaconda3\envs\20th_century\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\bhimc\anaconda3\envs\20th_century\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\bhimc\anaconda3\envs\20th_century\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\bhimc\anaconda3\envs\20th_century\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\bhimc\anaconda3\envs\20th_century\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in c:\users\bhimc\anaconda3\envs\20th_century\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\bhimc\anaconda3\envs\20th_century\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\bhimc\anaconda3\envs\20th_century\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\bhimc\anaconda3\envs\20th_century\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in c:\users\bhimc\anaconda3\envs\20th_century\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in c:\users\bhimc\anaconda3\envs\20th_century\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.9.4)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\bhimc\anaconda3\envs\20th_century\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\bhimc\anaconda3\envs\20th_century\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.66.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\bhimc\anaconda3\envs\20th_century\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.32.2)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\bhimc\anaconda3\envs\20th_century\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.7.3)
# Requirement already satisfied: jinja2 in c:\users\bhimc\anaconda3\envs\20th_century\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.1.4)
# Requirement already satisfied: setuptools in c:\users\bhimc\anaconda3\envs\20th_century\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (70.0.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\bhimc\anaconda3\envs\20th_century\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (24.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\bhimc\anaconda3\envs\20th_century\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.4.0)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\bhimc\anaconda3\envs\20th_century\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.26.4)
# Requirement already satisfied: language-data>=1.2 in c:\users\bhimc\anaconda3\envs\20th_century\lib\site-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.2.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\bhimc\anaconda3\envs\20th_century\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.4 in c:\users\bhimc\anaconda3\envs\20th_century\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.18.4)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\bhimc\anaconda3\envs\20th_century\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\bhimc\anaconda3\envs\20th_century\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\bhimc\anaconda3\envs\20th_century\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\bhimc\anaconda3\envs\20th_century\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\bhimc\anaconda3\envs\20th_century\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2024.2.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\bhimc\anaconda3\envs\20th_century\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\bhimc\anaconda3\envs\20th_century\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.1.5)
# Requirement already satisfied: colorama in c:\users\bhimc\anaconda3\envs\20th_century\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\bhimc\anaconda3\envs\20th_century\lib\site-packages (from typer<0.10.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in c:\users\bhimc\anaconda3\envs\20th_century\lib\site-packages (from weasel<0.4.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\bhimc\anaconda3\envs\20th_century\lib\site-packages (from jinja2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.1.5)
# Requirement already satisfied: marisa-trie>=0.7.7 in c:\users\bhimc\anaconda3\envs\20th_century\lib\site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.1.1)
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
# Load spacy English module
NER = spacy.load("en_core_web_sm")

# %% [markdown]
# ## 3. Load the twentieth-century text file

# %%
# Load the file
with open('key_events_of_20th_century.txt', 'r', errors='ignore') as file:
    data = file.read().replace('\n', '')

# %% [markdown]
# ## 4. Evaluate whether the text needs wrangling

# %% [markdown]
# #### I decided that the text file needed to be cleaned since there are stop wors and unnecessary puncation in the data. Cleaning the data file will give a cleaner version of text to analyze.

# %%
# Sentence tokenization

from nltk.tokenize import sent_tokenize
tokenized_sent = sent_tokenize(data)

# %%
# Word tokenization

from nltk.tokenize import word_tokenize
tokenized_word = word_tokenize(data)

# %%
# Defining stopwords

from nltk.corpus import stopwords
stop_words = set(stopwords.words("english"))

# %%
# Removing stopwords in words

filtered_words = [] # creates an empty list
for word in tokenized_word:
    if word not in stop_words:
        filtered_words.append(word)

# %%
# Substitute all punctuation marks with a space

sans_punc = re.sub("[^a-zA-Z]",  # Search for all non-letters
                        " ",        # Replace all non-letters with spaces
                        str(filtered_words))

# %%
# Word tokenization

tokenized_word_2 = word_tokenize(sans_punc)

# %%
new_stopwords = ["And", "Then", 'n', 't', 's', 'The', 'In', 'would', 'S', 'II', 'would', 'p']

# %%
filtered = []
for word in tokenized_word_2:
    if word not in new_stopwords:
        filtered.append(word)

# %%
#Combine the words
listToStr = ' '.join([str(elem) for elem in filtered])

# %%
#Exporting Text File
with open('KeyEvents_20thCentury_WrangledData.txt', 'w') as textfile:
    textfile.write(listToStr)

# %% [markdown]
# ## 5. Create NER objects

# %%
# Creating the NER object
book = NER(listToStr)

# %%
# Visualize identified entities
displacy.render(book[27:200], style = "ent", jupyter = True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Log Pages
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  logged editors learn moreContributionsTalkContentsmove sidebarhide Top Events th centuryToggle Events th century subsection world beginning century war end wars
# <mark class="entity" style="background: #ffeb80; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     World War I Russian Revolution Communism Between
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">EVENT</span>
# </mark>
#  wars Economic depression rise dictatorship
# <mark class="entity" style="background: #ffeb80; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Global war World War war
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">EVENT</span>
# </mark>
#  Europe Blitzkrieg Operation Barbarossa Turning tides Operation Overlord Final
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     days
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  war
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Pacific Background Japanese Expansion
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  Allied offensive Final days Holocaust Nuclear Age begins post war world end empires decolonization
# <mark class="entity" style="background: #ffeb80; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Cold War War
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">EVENT</span>
# </mark>
#  proxy space race end
# <mark class="entity" style="background: #ffeb80; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Cold War Information
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">EVENT</span>
# </mark>
#  communications technology world end century See also
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     References Sources External
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  linksToggle table contentsKey events th century languages Edit linksArticleTalkEnglishReadEditView historyToolsToolsmove sidebarhide Actions ReadEditView history General What links hereRelated changesUpload fileSpecial pagesPermanent linkPage informationCite pageGet shortened
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     URLDownload
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  QR codeWikidata item Print export
# <mark class="entity" style="background: #9cc9cc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Download PDFPrintable
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FAC</span>
# </mark>
#  version projects
# <mark class="entity" style="background: #9cc9cc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wikimedia CommonsFrom Wikipedia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FAC</span>
# </mark>
#  free encyclopediaThe th century changed world unprecedented ways
# <mark class="entity" style="background: #ffeb80; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     World Wars
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">EVENT</span>
# </mark>
#  sparked tension countries led creation atomic bombs
# <mark class="entity" style="background: #ffeb80; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Cold War led Space Race
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">EVENT</span>
# </mark>
#  creation space based rockets
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     World Wide Web
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
#  created These advancements played significant role citizens lives shaped st century today Events th
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     century
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  edit world beginning century </div></span>

# %% [markdown]
# ## 6. Split the sentence entities from the NER object

# %%
df_sentences = [] # empty shell to store results

# Loop through sentences, get entity list for each sentence
for sent in book.sents:
    entity_list = [ent.text for ent in sent.ents]
    df_sentences.append({"sentence": sent, "entities": entity_list})
    
df_sentences = pd.DataFrame(df_sentences)

# %%
df_sentences.head(20)
# Out:
#                                              sentence  \
# 0   (Key, events, th, century, WikipediaJump, cont...
# 1   (Create, account, Log, Pages, logged, editors,...
# 2   (Operation, Overlord, Final, days, war, Pacifi...
# 3   (See, also, References, Sources, External, lin...
# 4                                  (history, General)
# 5   (What, links, hereRelated, changesUpload, file...
# 6   (Wikimedia, CommonsFrom, Wikipedia, free, ency...
# 7   (Kaiser, Wilhelm, Much, map, Europe, redrawn, ...
# 8   (However, European, revolutions, defeated, Vla...
# 9   (Many, people, saw, first, stage, end, capital...
# 10  (economic, downturn, Hitler, began, put, plan,...
# 11  (He, negotiated, annexation, Sudetenland, Germ...
# 12  (This, treaty, gave, Stalin, free, rein, take,...
# 13                       (Estonia, Latvia, Lithuania)
# 14  (well, Eastern, Poland, remain, Soviet, posses...
# 15  (Denmark, surrendered, four, days, Sweden, Sca...
# 16                                    (Vichy, France)
# 17  (However, members, escaped, French, Army, form...
# 18  (He, ordered, generals, draw, plans, invasion,...
# 19  (Therefore, Soviet, army, largely, unprepared,...
#
#                                              entities
# 0   [Navigation Main, WikipediaContact, Contribute...
# 1   [Log Pages, World War I Russian Revolution Com...
# 2   [days, Pacific Background Japanese Expansion, ...
# 3                       [References Sources External]
# 4                                                  []
# 5                [URLDownload, Download PDFPrintable]
# 6   [Wikimedia CommonsFrom Wikipedia, World Wars, ...
# 7   [Kaiser Wilhelm, Europe, Yugoslavia, Czechoslo...
# 8   [European, Vladimir Lenin, Joseph Stalin, Leon...
# 9   [first, Soviet Union, Dorothea Lange, Migrant ...
# 10       [Hitler, Austria Anschluss, Austria Germany]
# 11  [Sudetenland German, Czechoslovakia Munich Con...
# 12                                   [Stalin, Baltic]
# 13                       [Estonia, Latvia, Lithuania]
# 14  [Eastern Poland, Soviet, Stalin, Finland, Sovi...
# 15  [Denmark, four days, Sweden, Scandinavian, Ger...
# 16                                           [France]
# 17  [French Army, Charles de Gaulle, French, Hitle...
# 18  [Operation Sea Lion, Luftwaffe, British, Battl...
# 19  [Soviet, Stalin, Germans, German, Army Group A...

# %% [markdown]
# ## 7. Filter the entities so that you end up only with the ones from your countries list

# %%
# Import countries
country_df = pd.read_csv("countries_list.csv", index_col = 0)

# %%
country_df.head(10)
# Out:
#                Country  Times mentioned
# 0          Afghanistan                1
# 1              Albania                2
# 2              Algeria                1
# 3              Andorra                0
# 4               Angola                1
# 5  Antigua and Barbuda                0
# 6            Argentina                0
# 7              Armenia                0
# 8            Australia                2
# 9              Austria                5

# %%
# Function to filter out entities not of interest

def filter_entity(ent_list, country_df):
    return [ent for ent in ent_list 
            if ent in list(country_df['Country'])]

# %%
# Check

filter_entity(["Australia"], country_df)
# Out:
# ['Australia']

# %%
df_sentences['country_entities'] = df_sentences['entities'].apply(lambda x: filter_entity(x, country_df))

# %%
df_sentences['country_entities'].head(20)
# Out:
# 0                                                    []
# 1                                                    []
# 2                                                    []
# 3                                                    []
# 4                                                    []
# 5                                                    []
# 6     [France, Italy, Russia, Germany, Austria, Hung...
# 7                                                    []
# 8                                                    []
# 9     [Germany, Italy, Germany, Germany, Germany, Un...
# 10                                                   []
# 11    [Spain, France, Poland, Poland, France, German...
# 12                                                   []
# 13                         [Estonia, Latvia, Lithuania]
# 14    [Finland, Germany, Poland, Luxembourg, Norway,...
# 15            [Denmark, Sweden, France, France, France]
# 16                                             [France]
# 17                              [France, Italy, Greece]
# 18                   [Germany, Greece, Albania, Greece]
# 19                    [Libya, Egypt, Egypt, Iraq, Iran]
# Name: country_entities, dtype: object

# %%
# Filter out sentences that don't have any character entities

df_sentences_filtered = df_sentences[df_sentences['country_entities'].map(len) > 0]

# %%
df_sentences_filtered.tail(10)
# Out:
#                                               sentence  \
# 95   (We, Can, Still, Learn, From, It, Time, Retrie...
# 96   (Retrieved, Forgotten, Reason, Why, Japan, Att...
# 103  (ONLINE, Retrieved, Andrew, Glass, August, Hir...
# 109  (Retrieved, Kirsch, Adam, April, System, Two, ...
# 118  (Preparatory, Commission, Comprehensive, Nucle...
# 119  (Retrieved, Why, Did, League, Nations, Fail, w...
# 120  (Portuguese, Africa, Oxford, Research, Encyclo...
# 122  (Africa, Retrieved, Yalta, Conference, Cold, W...
# 129  (Fall, Saigon, Time, Retrieved, Woollacott, Ma...
# 144  (Guardian, ISSN, Retrieved, Corstange, Daniel,...
#
#                                               entities  \
# 95   [Sino Japanese War Anti Japanese War Eight Yea...
# 96   [Japan, Pearl Harbor National Interest, United...
# 103  [Andrew Glass, August, Hirohito, Japan, Aug PO...
# 109  [Two, Nazi, December, Perspectives Clinical Re...
# 118  [BBC News, Retrieved Nuclear, Stockholm Intern...
# 119  [Retrieved Why Did League Nations Fail, un, St...
# 120  [Portuguese, Africa Oxford Research Encycloped...
# 122  [Cold War, March, Roberts Geoffrey, World War ...
# 129  [Saigon Time, Woollacott Martin, April, Forty ...
# 144  [Guardian ISSN Retrieved Corstange, Middle Eas...
#
#                   country_entities
# 95                  [Italy, Japan]
# 96   [Japan, United States, Japan]
# 103                        [Japan]
# 109                       [Israel]
# 118                         [Iran]
# 119                        [India]
# 120                  [Afghanistan]
# 122                       [Russia]
# 129                      [Vietnam]
# 144                        [India]

# %% [markdown]
# ## 8. Create the relationship dataframe

# %%
# Defining relationships 

# window size = 5 : this defines how many sentences will be looked at simultaneously 
relationships = [] # create an empty list

for i in range(df_sentences_filtered.index[-1]):
    end_i = min(i+5, df_sentences_filtered.index[-1])
    char_list = sum((df_sentences_filtered.loc[i: end_i].country_entities), [])
    
    # Remove duplicated characters that are next to each other
    char_unique = [char_list[i] for i in range(len(char_list)) 
                   if (i==0) or char_list[i] != char_list[i-1]]
    
    if len(char_unique) > 1:
        for idx, a in enumerate(char_unique[:-1]):
            b = char_unique[idx + 1]
            relationships.append({"source": a, "target": b})

# %%
relationship_df = pd.DataFrame(relationships)

# %%
relationship_df
# Out:
#           source       target
# 0         France        Italy
# 1          Italy       Russia
# 2         Russia      Germany
# 3        Germany      Austria
# 4        Austria      Hungary
# ..           ...          ...
# 745        India  Afghanistan
# 746  Afghanistan       Russia
# 747        India  Afghanistan
# 748  Afghanistan       Russia
# 749  Afghanistan       Russia
#
# [750 rows x 2 columns]

# %%
# Sort the cases with a- >b and b- >a
relationship_df = pd.DataFrame(np.sort(relationship_df.values, axis = 1), columns = relationship_df.columns)
relationship_df.head(5)
# Out:
#     source   target
# 0   France    Italy
# 1    Italy   Russia
# 2  Germany   Russia
# 3  Austria  Germany
# 4  Austria  Hungary

# %%
relationship_df["value"] = 1
relationship_df = relationship_df.groupby(["source","target"], sort=False, as_index=False).sum()

relationship_df.head(10)
# Out:
#      source         target  value
# 0    France          Italy     15
# 1     Italy         Russia      6
# 2   Germany         Russia     18
# 3   Austria        Germany      6
# 4   Austria        Hungary      6
# 5  Bulgaria        Hungary      6
# 6  Bulgaria         Russia      6
# 7   Germany        Ukraine     12
# 8   Germany          Italy     18
# 9   Germany  United States     17

# %% [markdown]
# ## 9. Save and expport your dataframe

# %%
# Export Relationship
relationship_df.to_csv('key_events_20th_century_relationship.csv')
